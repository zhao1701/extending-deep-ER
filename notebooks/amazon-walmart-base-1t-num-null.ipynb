# %%
import sys
import os
import re
sys.path.append('../scripts')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import helpers as hp
import pickle as pkl
import itertools as it

from collections import OrderedDict, defaultdict

from sklearn.metrics import f1_score, precision_score, recall_score,\
                            average_precision_score, roc_auc_score,\
                            roc_curve, precision_recall_curve, confusion_matrix,\
                            accuracy_score, classification_report

from IPython.core.interactiveshell import InteractiveShell
from matplotlib import rcParams
from importlib import reload
from model_generator import deep_er_model_generator
pd.options.display.max_colwidth = 1000

rcParams['font.family'] = 'serif'
rcParams['font.serif'] = 'times new roman'

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# /home/paperspace/anaconda3/envs/python-36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Load data

# %%
reload(hp)

with open('../data/converted/amazon-walmart-reduced/glove-300.map', 'rb') as f:
    map = pkl.load(f)

data_dir = os.path.join('..','data')
source_dir = os.path.join(data_dir,'split','amazon-walmart-reduced')
data = hp.load_data(source_dir)

datasets = ['train_1', 'val_1', 'test_1', 'train_2', 'val_2', 'test_2']

for data_name in data.keys():
    data[data_name] = data[data_name].fillna(0)

doc_freqs_1, doc_freqs_2 = hp.get_document_frequencies('../data/converted/amazon-walmart-reduced/', mapping=map)
nan_idx = map['word2idx']['NaN']

# %% [markdown]
# # Generate model

# %%
histories = dict(acc=list(), val_acc=list(), loss=list(), val_loss=list())
model, X_train, X_val, X_test, y_train, y_val, y_test = \
deep_er_model_generator(data,
                        embedding_file = '../data/converted/amazon-walmart-reduced/glove-300.matrix.npy',
                        text_columns = ['brand', 'groupname', 'title', 'shelfdescr',
                                        'shortdescr', 'longdescr'],
                        numeric_columns = ['price', 'shipweight', 'length',
                                           'width', 'height'],
                        text_nan_idx=nan_idx,
                        num_nan_val=0,
                        text_sim_metrics=['cosine'],
                        text_compositions=['average'],
                        numeric_sim_metrics=['min_max_ratio',
                                             'unscaled_inverse_lp',
                                             'scaled_inverse_lp'],
                        dense_nodes=[32, 16, 8],
                        document_frequencies=(doc_freqs_1, doc_freqs_2),
                        idf_smoothing=2,
                        make_isna=True,
                        embedding_trainable=True)
# Out:
# Number of inputs to dense layer: 43

# %% [markdown]
# # Train model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=1, batch_size=2048,
                    validation_data=(X_val, y_val),
                    shuffle=True)

histories['acc'].extend(history.history['acc'])
histories['val_acc'].extend(history.history['val_acc'])
histories['loss'].extend(history.history['loss'])
histories['val_loss'].extend(history.history['val_loss'])
# Out:
# Train on 93243 samples, validate on 11656 samples
# Epoch 1/1
# 93243/93243 [==============================] - 13s 144us/step - loss: 5.5415e-04 - acc: 0.9998 - val_loss: 0.0090 - val_acc: 0.9985

# %% [markdown]
# # Learning curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,6))
axes[0].plot(histories['loss'], label='loss')
axes[0].plot(histories['val_loss'], label='val_loss')
axes[0].set_ylim(0, 0.05)
axes[1].plot(histories['acc'], label='acc')
axes[1].plot(histories['val_acc'], label='val_acc')
axes[1].set_ylim(0.98, 1)

for ax in axes:
    ax.legend()
    ax.grid(True)
    ax.set(xlabel='epoch')

# %% [markdown]
# # Evaluate model

# %%
y_val_pred = model.predict(X_val, batch_size=8192)[:,1]
y_val_ = data['val_y'].values.squeeze()
print(classification_report(y_val_, y_val_pred >= 0.5))
print(confusion_matrix(y_val_, y_val_pred >= 0.5))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11529
#           1       0.92      0.94      0.93       127
#
# avg / total       1.00      1.00      1.00     11656
#
# [[11519    10]
#  [    8   119]]

# %%
mapping = map.copy()
bool_mask = (y_val_ == 1) & ~(y_val_pred >= 0.5)
columns = ['brand', 'groupname', 'title', 'shelfdescr',
           'shortdescr', 'longdescr']
df_examine = hp.examine_data(data['val_1'], data['val_2'], columns, bool_mask, mapping)
df_examine.sample(5)
# Out:
#          id1              brand                          groupname  \
# 6184   19801            lanthem                  printer ink toner
# 7026   13660                      desk supplies holders dispensers
# 9062   17448               dymo             other office equipment
# 7762    9692            imation                        blank media
# 10490  14546   cables unlimited                        electronics
#
#                                                                          title  \
# 6184                           time vis6008  vis6008 ribbon purple  lthvis6008
# 7026     notes dispenser   inches   inches black includes one original  refill
# 9062              1754490  labelmanager 260p  lines  10w   9d   5h  dym1754490
# 7762                                        qic 250 mb 500 mb    storage media
# 10490                   cables unlimited tm   db25 parallel pci   card ioc1000
#
#        price  \
# 6184   39.08
# 7026   10.99
# 9062    0.00
# 7762   60.47
# 10490  29.99
#
#                                                                                                                                                                                                                                                                                                                                                             shelfdescr  \
# 6184                                                                                                                                                                     vis6008 ribbon  for use with latham 900e 1000e 1500e 5000ep 7000e and 7500e electronic time  accurate clear  device types  clock color  purple oem compatible  ribbon type   unit of measure
# 7026                                                                                                                                                                                                                                                                                    made of strong   neutral  size    inch includes one original  refill  neutral
# 9062                                                                                                                                                                                                                                                                                                                                                               nan
# 7762                                                                                                                                                                                                                                                                                                                       dc6250 data cartridge 250mb  sold by the ea
# 10490   perfect for use with external zip drives printers scanners tape drives or any other device that requires   parallel connection fully compatible with both pci  and ieee 1294 specifications easy   installation data transfer rates up to  times faster then comparable isa or motherboard parallel ports supports windows 95 98 98se me nt  2000 xp and vista
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      shortdescr  \
# 6184                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        nan
# 7026      what did you ever do without them  notes dispensers makes it simple to grab one note at   pick  traditional style for the office  trendy style for the home message center or  mounted style for vertical dispensing  having  busy day and need to get more done there   note for that the  x3 size is perfect for writing reminder notes to  work greener today for  brighter tomorrow all  notes are sfi chain of custody certified paper used comes from forests that are  where trees are  all  notes are also recyclable so please remember to  contains  pack of  original  dispenser  x3 in  also try  flag highlighters pens and markers available in  variety of colors and
# 9062                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        nan
# 7762                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        nan
# 10490                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       nan
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      longdescr  \
# 6184                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      for use with latham 900e 1000e 1500e 5000ep 7000e and 7500e electronic time  accurate clear  device types time clock color  purple oem compatible oem ribbon type   ribbon 1000e 7000e consumables transfer type printing publishing
# 7026    the  note was invented as  solution without   in 1968  spencer silver  3m scientist developed  unique repositionable  as remarkable as it was the product could not find   six years later colleague art fry recalled silver  seminars promoting the light adhesive when he was daydreaming about  bookmark that would stay put in his church  the rest is  today  boasts more than  000 unique products and has become one of the most  and beloved brands in the  are all  paper products recyclable  3m has conducted recycling trials on  notes at recycled paper  the adhesive does not interfere with paper recycling because the adhesive is substantially removed in the paper   the dyes in the paper are also removed in this part of the  are  notes made from recycled paper  many different colors and sizes of  notes are available with paper containing at least 30 percent  recycled  in addition 3m offers 100 percent recycled content notes in canary yellow and assorted pastel  the 100 percent recycled cont...
# 9062    eliminate the inconvenience of aa batteriesjust charge and go with this sleek  label  packed with new features inspired by labelmanager users to help you get the results you want with more ease and  the large        screen displays two lines of label  plus the graphical display lets you see text effects onscreen before you  works faster with an improved user interface that displays all menu options onscreen without scrolling and includes intuitive icons for formatting  familiar   offers quick access to special  choose from three font styles six font sizes and one of eight different box or underline  nine label memory and easy insertion of saved  prints up to 10 copies of the same  includes rechargeable lithium ion battery charging cord starter label cassette and user  tape size       number of printed lines  display characters  display lines 13   memory   label makers label  thermal transfer label printer label manager identifications classifications stickers creators producer roo...
# 7762                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              dc6250 data cartridge 250mb
# 10490                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           take full advantage of all your  parallel devices by adding this economical cables unlimited pci  this high performance epp ecp parallel card adds one ieee 1284 port to your  with data transfer rates up to  mbps this card is up to  times faster than  standard  parallel
#
#        shipweight length  ...                        groupname  \
# 6184          0.0    0.0  ...     stationery  office machinery
# 7026          0.0    4.2  ...     stationery  office machinery
# 9062          0.0    0.0  ...     stationery  office machinery
# 7762          0.0    6.4  ...                  mp3 accessories
# 10490         0.0    7.0  ...             electronics  general
#
#                                                                     title  \
# 6184                                    lathem time vis6008 ribbon purple
# 7026          notes professional series dispenser for      notes blk base
# 9062                                               dymo labelmanager 260p
# 7762                                  imation 46157 dc6250 data cartridge
# 10490   cables unlimited   port db25 parallel pci ecp epp spp port   card
#
#        price  \
# 6184   15.00
# 7026    9.94
# 9062   59.97
# 7762   38.88
# 10490  16.88
#
#                                                                                                                                                                                                    shelfdescr  \
# 6184                                                                                                                                            for use with latham 1000e and 7000e electronic time recorders
# 7026                                                                                                                           includes  note pad in canary yellow stylish design weighted to prevent lifting
# 9062                                                                                                                                                                   easy to use graphical display  buttons
# 7762                                                                                                  up to 18 tracks on tape recording densities fttpi 12500 storage capacity 250mb native  500mb compressed
# 10490   take full advantage of all your  parallel devices by adding this economical pci  perfect for use with external zip drives printers scanners tape drives or any other device that requires   parallel
#
#                                                                                                                                                                                                     shortdescr  \
# 6184                                                                                                                                      for use with latham 1000e and 7000e electronic time  accurate clear
# 7026                              the  notes professional series dispenser allows you to grab  notes quickly and easily with one  its practical design provides  professional look and complements any office
# 9062    eliminate the inconvenience of aa batteries just charge and go with this sleek  dymo  packed with new features inspired by labelmanager users to help you get the results you want with more ease and
# 7762                                                                                                                                                                       imation 46157 dc6250 data cartridge
# 10490    take full advantage of all your  parallel devices by adding this economical pci  perfect for use with external zip drives printers scanners tape drives or any other device that requires   parallel
#
#                                                                                                                                                                                                                                                                                                                                                                               longdescr  \
# 6184                                                                                                                                                                                lathem time vis6008 ribbon purple oem time recorder ribbon for latham 1000e and 7000e electronic time recorders for use with latham 1000e and 7000e electronic time recorders accurate clear output
# 7026                                                                                                                                                                                                                                                         notes professional series dispenser includes  50 sheet    note pad in canary yellow black base weighted to prevent lifting
# 9062          dymo labelmanager smartly designed  keyboard   buttons can bold underline and box font graphical display   customize labels with  different fonts  sizes and  different box or underline styles  memory can save text print up to 10 copies of the same label rechargeable lithium ion battery charging cord included has  starter label cassette and  user manual size
# 7762                                                                                                                                                                                                                            compatibility qic system 150 and qic system 120 up to 18 tracks on tape recording densities fttpi 12500 storage capacity 250mb native  500mb compressed
# 10490   this high performance epp ecp parallel card adds one ieee 1284 port to your  fully compatible with both pci  and ieee 1294  with data transfer rates up to  mbps this card is up to  times faster than  standard  parallel  data transfer rates up to  times faster then comparable isa or motherboard parallel  easy jumperless   supports windows 95 98 98se me nt  2000 and
#
#        shipweight length  width height
# 6184        0.049   0.00   0.00   0.00
# 7026        1.315   0.00   0.00   0.00
# 9062        2.090   0.00   0.00   0.00
# 7762        0.600   5.85   3.83   0.68
# 10490       0.200  17.32  14.57  13.89
#
# [5 rows x 24 columns]

# %% [markdown]
# # Save model and histories

# %%
pd.DataFrame(histories).to_csv('../data/histories/amazon-walmart-base-1t-num-null.csv', index=False)
model.save_weights('../data/models/amazon-walmart-base-1t-num-null')

# %% [markdown]
# # Test model

# %%
model.load_weights('../data/models/amazon-walmart-base-1t-num-null')
y_test_pred = model.predict(X_test, batch_size=4096)[:,1]
y_test_ = data['test_y'].values.squeeze()
print(classification_report(y_test_, y_test_pred >= 0.5, digits=5))
print(confusion_matrix(y_test_, y_test_pred >= 0.5))
# Out:
#              precision    recall  f1-score   support
#
#           0    0.99887   0.99879   0.99883     11541
#           1    0.87826   0.88596   0.88210       114
#
# avg / total    0.99769   0.99768   0.99769     11655
#
# [[11527    14]
#  [   13   101]]
