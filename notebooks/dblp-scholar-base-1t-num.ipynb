# %%
import sys
import os
import re
sys.path.append('../scripts')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import helpers as hp
import pickle as pkl
import itertools as it

from collections import OrderedDict, defaultdict

from sklearn.metrics import f1_score, precision_score, recall_score,\
                            average_precision_score, roc_auc_score,\
                            roc_curve, precision_recall_curve, confusion_matrix,\
                            accuracy_score, classification_report

from IPython.core.interactiveshell import InteractiveShell
from matplotlib import rcParams
from importlib import reload
from model_generator import deep_er_model_generator
pd.options.display.max_colwidth = 1000

rcParams['font.family'] = 'serif'
rcParams['font.serif'] = 'times new roman'

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# /home/paperspace/anaconda3/envs/python-36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Load data

# %%
reload(hp)

with open('../data/converted/dblp-scholar-reduced/glove-300.map', 'rb') as f:
    map = pkl.load(f)

data_dir = os.path.join('..','data')
source_dir = os.path.join(data_dir,'split','dblp-scholar-reduced')
data = hp.load_data(source_dir)

datasets = ['train_1', 'val_1', 'test_1', 'train_2', 'val_2', 'test_2']

for data_name in datasets:
    data[data_name] = data[data_name].fillna(0)

doc_freqs_1, doc_freqs_2 = hp.get_document_frequencies('../data/converted/dblp-scholar-reduced/', mapping=map)
nan_idx = map['word2idx']['NaN']

# %% [markdown]
# # Generate model

# %%
histories = dict(acc=list(), val_acc=list(), loss=list(), val_loss=list())
model, X_train, X_val, X_test, y_train, y_val, y_test = \
deep_er_model_generator(data,
                        embedding_file = '../data/converted/dblp-scholar-reduced/glove-300.matrix.npy',
                        text_columns = ['title', 'authors', 'venue'],
                        numeric_columns = ['year'],
                        text_nan_idx=nan_idx,
                        num_nan_val=0,
                        text_sim_metrics=['cosine'],
                        text_compositions=['average'],
                        numeric_sim_metrics=['min_max_ratio', 'scaled_inverse_lp', 'unscaled_inverse_lp'],
                        dense_nodes=[32, 16, 8],
                        document_frequencies=(doc_freqs_1, doc_freqs_2),
                        idf_smoothing=2,
                        make_isna=False,
                        embedding_trainable=True)
# Out:
# Number of inputs to dense layer: 6

# %% [markdown]
# # Train model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=1, batch_size=8192,
                    validation_data=(X_val, y_val),
                    shuffle=True)

histories['acc'].extend(history.history['acc'])
histories['val_acc'].extend(history.history['val_acc'])
histories['loss'].extend(history.history['loss'])
histories['val_loss'].extend(history.history['val_loss'])
# Out:
# Train on 432038 samples, validate on 54004 samples
# Epoch 1/1
# 432038/432038 [==============================] - 20s 47us/step - loss: 4.5125e-04 - acc: 0.9999 - val_loss: 0.0014 - val_acc: 0.9996

# %% [markdown]
# # Learning curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,6))
axes[0].plot(histories['loss'], label='loss')
axes[0].plot(histories['val_loss'], label='val_loss')
axes[1].plot(histories['acc'], label='acc')
axes[1].plot(histories['val_acc'], label='val_acc')

for ax in axes:
    ax.legend()
    ax.grid(True)
    ax.set(xlabel='epoch')

# %% [markdown]
# # Evaluate model

# %%
y_val_pred = model.predict(X_val, batch_size=8192)[:,1]
y_val_ = data['val_y'].values.squeeze()
print(classification_report(y_val_, y_val_pred >= 0.5))
print(confusion_matrix(y_val_, y_val_pred >= 0.5))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     53474
#           1       0.99      0.97      0.98       530
#
# avg / total       1.00      1.00      1.00     54004
#
# [[53467     7]
#  [   16   514]]

# %%
mapping = map.copy()
bool_mask = (y_val_ == 1) & ~(y_val_pred >= 0.5)
columns = ['title', 'authors', 'venue']
df_examine = hp.examine_data(data['val_1'], data['val_2'], columns, bool_mask, mapping)
df_examine
# Out:
#                                id1  \
# 1026          conf/vldb/AgrawalS94
# 7157           conf/vldb/BonczMK99
# 11699        conf/sigmod/ZhaoDNS98
# 13046     conf/sigmod/FaloutsosL95
# 13493    conf/vldb/HellersteinNP95
# 17181   journals/sigmod/CasatiDS00
# 18381       conf/sigmod/LiYVGPUV98
# 26225      conf/vldb/FaloutsosJS97
# 26814         conf/vldb/GyssensL97
# 29770   journals/tods/ChaudhuriS99
# 30625   conf/sigmod/ImielinskiVB94
# 31113   conf/sigmod/GeneserethKD97
# 31930      conf/sigmod/GravanoGT94
# 35689    journals/sigmod/MeltonE02
# 36199      journals/vldb/ShyyASL96
# 51310  conf/sigmod/DogacAEOADAOS94
#
#                                                                                                    title  \
# 1026                                     fast algorithms for mining association rules in large databases
# 7157                               database architecture optimized for the new bottleneck  memory access
# 11699                           simultaneous optimization and evaluation of multiple dimensional queries
# 13046   fastmap   fast algorithm for indexing   and visualization of traditional and multimedia datasets
# 13493                                                      generalized search trees for database systems
# 17181                                                            vldb workshop on technologies in   tes
# 18381                                                              capability based mediation in tsimmis
# 26225                                                           recovering information from summary data
# 26814                                                                          foundation for  databases
# 29770                                                           optimization of queries with  predicates
# 30625                                                                   energy efficient indexing on air
# 31113                                                      infomaster  an information integration system
# 31930                                 the effectiveness of gloss for the text database discovery problem
# 35689                                                                            an early look at xquery
# 36199                               the design and implementation of      programming language of osam
# 51310                                                                                         metu  dbms
#
#                                                                                      authors  \
# 1026                                                                       agrawal   srikant
# 7157                                                              boncz   manegold   kersten
# 11699                                                   zhao   deshpande   naughton   shukla
# 13046                                                                        faloutsos   lin
# 13493                                                       hellerstein   naughton   pfeffer
# 17181                                                                                    nan
# 18381                      li   yerneni   vassalos      papakonstantinou   ullman   valiveti
# 26225                                                    faloutsos   jagadish   sidiropoulos
# 26814                                                                   gyssens   lakshmanan
# 29770                                                                       chaudhuri   shim
# 30625                                                   imielinski   viswanathan   badrinath
# 31113                                                          genesereth   keller   duschka
# 31930                                                                   gravano      tomasic
# 35689                                                                     melton   eisenberg
# 36199                                                               shyy   arroyo   su   lam
# 51310    dogac   arpinar   evrendilek   ozkan   altintas   durusoy   altinel   okay   saygin
#
#                     venue  year           id2  \
# 1026                 vldb  1994  3MzTom30SiMJ
# 7157                 vldb  1999  6GAoBRINv7kJ
# 11699   sigmod conference  1998  6AK0GF7jAtsJ
# 13046   sigmod conference  1995  j0EcM-BvshwJ
# 13493                vldb  1995  SA4P684zTf4J
# 17181                 nan  2000  pJsnj7fi9LIJ
# 18381   sigmod conference  1998  fOQEOEdh-mcJ
# 26225                vldb  1997  TyxKh_eSfCIJ
# 26814                vldb  1997  CfujBHjOpPAJ
# 29770      acm  database   1999  31oH64SXpRcJ
# 30625   sigmod conference  1994  CuoOi5jJXxQJ
# 31113   sigmod conference  1997  V1GBio3oeqMJ
# 31930   sigmod conference  1994  OYFpMlm5yCQJ
# 35689       sigmod record  2002  IqEw9ssJ2QAJ
# 36199               vldb   1996  1J2ubL0l2UMJ
# 51310   sigmod conference  1994  fsa72WmA67kJ
#
#                                                                                               title  \
# 1026                                                      fastalgorithmsformining association rules
# 7157                                databasearchitecture optimizedforthenewbottleneck  memoryaccess
# 11699   pm deshpande  jf naughton   shukla     simultaneous optimization and evaluation of multiple
# 13046                                                         fastmap   fast algorithm for indexing
# 13493                                                      generalizedsearchtreesfordatabasesystems
# 17181      report on the vldb workshop on technologies for   tes  cairo  egypt september 14 and 15
# 18381                                                                          mediation in tsimmis
# 26225                                                       recovering informationfrom summary data
# 26814                                            foundation for   in  dayal   gray pmd  nishio  eds
# 29770                                               optimizationofquerieswithuserdefined predicates
# 30625                                                                 energy efficientindexingonair
# 31113         infomaster  an information integration   in proceedings of 1997 acm sigmod conference
# 31930                                                     garc   and   the eectivenessof gloss for
# 35689                                                 an early look at xquery api for java tm  xqj
# 36199                        knowledge base programming language for advanced database applications
# 51310                                                                         metu  database system
#
#                                          authors  \
# 1026                                 rar srikant
# 7157                  boncz   manegold   kersten
# 11699                                       zhao
# 13046                          faloutsos  ki lin
# 13493                jm hellerstein  jf naughton
# 17181                                     casati
# 18381                               li   yerneni
# 26225    faloutsos  hv jagadish  nd sidiropoulos
# 26814                    gyssens  lvs lakshmanan
# 29770                           chaudhuri   shim
# 30625     imielinski   viswanathan  br badrinath
# 31113         mr genesereth  am keller   duschka
# 31930                                    gravano
# 35689                                  eisenberg
# 36199                                    ym shyy
# 51310
#
#                                                             venue    year
# 1026          of the vldb conference  santiago  chile  september      0.0
# 7157     25th international conference on very large data bases       0.0
# 11699                                                  acm sigmod     0.0
# 13046           and visualization of traditional and multimedia       0.0
# 13493                               21st   very large data bases      0.0
# 17181                                              sigmod record   2000.0
# 18381                                          sigmod conference      0.0
# 26225                                                         nan     0.0
# 26814                                                         nan  1997.0
# 29770                                                         nan  1996.0
# 30625                                                   of1994acm     0.0
# 31113                                                         nan  1997.0
# 31930         proceedings of the 1994 acm sigmod conference  may      0.0
# 35689                                              sigmod record   2004.0
# 36199                                                         nan     0.0
# 51310                 demo description  in the  acm sigmod   on       0.0

# %% [markdown]
# # Save model and histories

# %%
pd.DataFrame(histories).to_csv('../data/histories/dblp-scholar-base-1t-num.csv', index=False)
model.save_weights('../data/models/dblp-scholar-base-1t-num')

# %% [markdown]
# # Test model

# %%
model.load_weights('../data/models/dblp-scholar-base-1t-num')
y_test_pred = model.predict(X_test, batch_size=8192)[:,1]
y_test_ = data['test_y'].values.squeeze()
print(classification_report(y_test_, y_test_pred >= 0.5, digits=5))
print(confusion_matrix(y_test_, y_test_pred >= 0.5))
# Out:
#              precision    recall  f1-score   support
#
#           0    0.99961   0.99994   0.99978     53467
#           1    0.99423   0.96097   0.97732       538
#
# avg / total    0.99955   0.99956   0.99955     54005
#
# [[53464     3]
#  [   21   517]]
