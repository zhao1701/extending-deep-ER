# %%
import sys
import os
import re
sys.path.append('../scripts')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import helpers as hp
import pickle as pkl
import itertools as it

from collections import OrderedDict, defaultdict

from sklearn.metrics import f1_score, precision_score, recall_score,\
                            average_precision_score, roc_auc_score,\
                            roc_curve, precision_recall_curve, confusion_matrix,\
                            accuracy_score, classification_report

from IPython.core.interactiveshell import InteractiveShell
from matplotlib import rcParams
from importlib import reload
from model_generator import deep_er_model_generator
pd.options.display.max_colwidth = 1000

rcParams['font.family'] = 'serif'
rcParams['font.serif'] = 'times new roman'

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# /home/paperspace/anaconda3/envs/python-36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Load data

# %%
reload(hp)

with open('../data/converted/dblp-scholar-reduced/glove-300.map', 'rb') as f:
    map = pkl.load(f)

data_dir = os.path.join('..','data')
source_dir = os.path.join(data_dir,'split','dblp-scholar-reduced')
data = hp.load_data(source_dir)

datasets = ['train_1', 'val_1', 'test_1', 'train_2', 'val_2', 'test_2']

for data_name in datasets:
    data[data_name] = data[data_name].fillna(0)

doc_freqs_1, doc_freqs_2 = hp.get_document_frequencies('../data/converted/dblp-scholar-reduced/', mapping=map)
nan_idx = map['word2idx']['NaN']

# %% [markdown]
# # Generate model

# %%
histories = dict(acc=list(), val_acc=list(), loss=list(), val_loss=list())
model, X_train, X_val, X_test, y_train, y_val, y_test = \
deep_er_model_generator(data,
                        embedding_file = '../data/converted/dblp-scholar-reduced/glove-300.matrix.npy',
                        text_columns = ['title', 'authors', 'venue'],
                        numeric_columns = [],
                        text_nan_idx=nan_idx,
                        num_nan_val=0,
                        text_sim_metrics=['cosine', 'inverse_l1'],
                        text_compositions=['bi_lstm'],
                        numeric_sim_metrics=[],
                        dense_nodes=[32, 16],
                        document_frequencies=(doc_freqs_1, doc_freqs_2),
                        idf_smoothing=2,
                        make_isna=False,
                        lstm_args=dict(units=25, dropout=0, recurrent_dropout=0),
                        batch_norm=True,
                        dropout=0.5)
# Out:
# Number of inputs to dense layer: 87

# %% [markdown]
# # Crash recovery

# %%
model.load_weights('../data/models/dblp-scholar-base-2-allsim')
df_hist = pd.read_csv('../data/histories/dblp-scholar-base-2-allsim.csv')

histories['acc'] = list(df_hist['acc'].values)
histories['val_acc'] = list(df_hist['val_acc'].values)
histories['loss'] = list(df_hist['loss'].values)
histories['val_loss'] = list(df_hist['val_loss'].values)

# %% [markdown]
# # Train model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=1, batch_size=8192,
                    validation_data=(X_val, y_val),
                    shuffle=True)

histories['acc'].extend(history.history['acc'])
histories['val_acc'].extend(history.history['val_acc'])
histories['loss'].extend(history.history['loss'])
histories['val_loss'].extend(history.history['val_loss'])
# Out:
# Train on 432038 samples, validate on 54004 samples
# Epoch 1/1
# 432038/432038 [==============================] - 149s 344us/step - loss: 0.0015 - acc: 0.9997 - val_loss: 0.0033 - val_acc: 0.9995

# %% [markdown]
# # Learning curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,6))
axes[0].plot(histories['loss'], label='loss')
axes[0].plot(histories['val_loss'], label='val_loss')
axes[0].set_ylim(0, 0.02)
axes[1].plot(histories['acc'], label='acc')
axes[1].plot(histories['val_acc'], label='val_acc')
axes[1].set_ylim(0.998, 1)

for ax in axes:
    ax.legend()
    ax.grid(True)
    ax.set(xlabel='epoch')

# %% [markdown]
# # Evaluate model

# %%
y_val_pred = model.predict(X_val, batch_size=8192)[:,1]
y_val_ = data['val_y'].values.squeeze()
print(classification_report(y_val_, y_val_pred >= 0.5))
print(confusion_matrix(y_val_, y_val_pred >= 0.5))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     53474
#           1       0.99      0.96      0.98       530
#
# avg / total       1.00      1.00      1.00     54004
#
# [[53469     5]
#  [   20   510]]

# %%
mapping = map.copy()
bool_mask = (y_val_ == 1) & ~(y_val_pred >= 0.5)
columns = ['title', 'authors', 'venue']
df_examine = hp.examine_data(data['val_1'], data['val_2'], columns, bool_mask, mapping)
df_examine.sample(5)
# Out:
#                              id1  \
# 17041   conf/sigmod/FaloutsosL95
# 31899       conf/vldb/SrikantA95
# 7157         conf/vldb/BonczMK99
# 40247      conf/sigmod/HanFHCC94
# 29679  conf/sigmod/SaltenisJLL00
#
#                                                                                                    title  \
# 17041   fastmap   fast algorithm for indexing   and visualization of traditional and multimedia datasets
# 31899                                                               mining generalized association rules
# 7157                               database architecture optimized for the new bottleneck  memory access
# 40247                         dblearn   system prototype for knowledge discovery in relational databases
# 29679                                              indexing the positions of continuously moving objects
#
#                                          authors               venue  year  \
# 17041                            faloutsos   lin   sigmod conference  1995
# 31899                          srikant   agrawal                vldb  1995
# 7157                  boncz   manegold   kersten                vldb  1999
# 40247           han   fu   huang   cai   cercone   sigmod conference  1994
# 29679    saltenis   jensen   leutenegger   lopez   sigmod conference  2000
#
#                 id2  \
# 17041  43b8e16YZlEJ
# 31899  kAi6HssDySgJ
# 7157   6GAoBRINv7kJ
# 40247  bJLqgUjkbNEJ
# 29679  LMm4_4_uNNoJ
#
#                                                                                                    title  \
# 17041                     und lin    1995   fastmap   fast algorithm for indexing   and visualization of
# 31899                                                                fast  for mining assoiciation rules
# 7157                                     databasearchitecture optimizedforthenewbottleneck  memoryaccess
# 40247                          advances of the dblearn system for knowledge discovery in large databases
# 29679   bindexing the positions of continuously moving objects   in proceedings of the acm international
#
#                                                authors  \
# 17041                                        faloutsos
# 31899                                agrawal   srikant
# 7157                        boncz   manegold   kersten
# 40247                                  han   fu   tang
# 29679    saltenis  cs jensen  st leutenegger  ma lopez
#
#                                                             venue    year
# 17041         proceedings of the 1995  acm  sigmod  on management     0.0
# 31899                                              the 20th vldb      0.0
# 7157     25th international conference on very large data bases       0.0
# 40247                                                         nan     0.0
# 29679                                                         nan  2000.0

# %% [markdown]
# # Save model and histories

# %%
pd.DataFrame(histories).to_csv('../data/histories/dblp-scholar-base-2-allsim.csv', index=False)
model.save_weights('../data/models/dblp-scholar-base-2-allsim')

# %% [markdown]
# # Test model

# %%
model.load_weights('../data/models/dblp-scholar-base-2-allsim')
y_test_pred = model.predict(X_test, batch_size=8192)[:,1]
y_test_ = data['test_y'].values.squeeze()
print(classification_report(y_test_, y_test_pred >= 0.5, digits=5))
print(confusion_matrix(y_test_, y_test_pred >= 0.5))
# Out:
#              precision    recall  f1-score   support
#
#           0    0.99963   0.99993   0.99978     53467
#           1    0.99234   0.96283   0.97736       538
#
# avg / total    0.99955   0.99956   0.99955     54005
#
# [[53463     4]
#  [   20   518]]
