# %%
# %%writefile convert-text.py
import pandas as pd
import numpy as np
import pickle as pkl
import argparse as ap

import os
import re
import string
import html

from collections import defaultdict

parser = ap.ArgumentParser()
parser.add_argument('source_dir',
                    help='directory containing dataset and match files to split')
parser.add_argument('dest_dir',
                    help='directory to save split dataset csvs')
parser.add_argument('mapping_file',
                    help='double dictionary containing maps to-from words\
                          and vocabulary indices')
parser.add_argument('--set1', '-s1', default='set1.csv',
                    help='filename of first dataset csv')
parser.add_argument('--set2', '-s2', default='set2.csv',
                    help='filename of second dataset csv')
parser.add_argument('--matches', '-m', default='matches.csv',
                    help='filename of positives matches csv')
parser.add_argument('--indices', '-i', nargs='+', type=int,
                    help='indices of columns to be converted (starting from 0)')
parser.add_argument('--verbose', '-v', action='store_true',
                    help='print statistics')

# parse command line arguments
args = parser.parse_args()
source_dir = args.source_dir
dest_dir = args.dest_dir
mapping_file = args.mapping_file
column_idxs = args.indices

verbose = args.verbose

set1 = args.set1
set2 = args.set2
matches = args.matches

if verbose:
    print('Loading datasets and maps.')
# load data
# df_pos is loaded so that it can be copied to destination directory
df1 = pd.read_csv(os.path.join(source_dir, set1), encoding = "latin1")
df2 = pd.read_csv(os.path.join(source_dir, set2), encoding = "latin1")
df_pos = pd.read_csv(os.path.join(source_dir, matches), encoding = "latin1")

# load double dictionary
with open(mapping_file, 'rb') as f:
    map = pkl.load(f)

# change word2idx to a default dictionary that outputs 0 for unknown tokens
map['word2idx'] = defaultdict(int, map['word2idx'])

def clean_text(x):
    "formats a single string"
    if not isinstance(x, str):
        return 'NaN'
    
    # separate possessives with spaces
    x = x.replace('\'s', ' \'s')
    
    # convert html escape characters to regular characters
    x = html.unescape(x)
    
    # separate punctuations with spaces
    def pad(x):
        match = re.findall(r'.', x[0])[0]
        match_clean = ' ' + match + ' '
        return match_clean
    rx = r'\(|\)|/|!|#|\$|%|&|\\|\*|\+|,|:|;|<|=|>|\?|@|\[|\]|\^|_|{|}|\||'
    rx += r'`|~'
    x = re.sub(rx, pad, x)
    
    # remove decimal parts of version numbers
    def v_int(x):
        return re.sub('\.\d+','',x[0])
    x = re.sub(r'v\d+\.\d+', v_int, x)
    
    return x

if verbose:
    print('Cleaning the following columns from set1:')
    for column in df1.columns[column_idxs]:
        print(column, end=' ')
    print()
    print('Cleaning the following columns from set2:')
    for column in df2.columns[column_idxs]:
        print(column, end=' ')
    print()

df1.iloc[:, column_idxs] = df1.iloc[:, column_idxs].applymap(clean_text)
df2.iloc[:, column_idxs] = df2.iloc[:, column_idxs].applymap(clean_text)

def record2idx(x):
    x = x.split()
    for i, token in enumerate(x):
        idx = map['word2idx'][token]
        if idx == 0:
            idx = map['word2idx'][token.lower()]
        if idx == 0:
            idx = map['word2idx'][string.capwords(token)]
        if idx == 0:
            idx = map['word2idx'][token.upper()]
        x[i] = idx
    return x

if verbose:
    print('Converting tokens to indices.')
df1.iloc[:, column_idxs] = df1.iloc[:, column_idxs].applymap(record2idx)
df2.iloc[:, column_idxs] = df2.iloc[:, column_idxs].applymap(record2idx)

if not os.path.isdir(dest_dir):
    os.mkdir(dest_dir)
    if verbose:
        print('Creating destination directory')
    
df1.to_csv(os.path.join(dest_dir, set1), index=False)
df2.to_csv(os.path.join(dest_dir, set2), index=False)
df_pos.to_csv(os.path.join(dest_dir, matches), index=False)
# Out:
# Overwriting convert-text.py

# %% [markdown]
# # Prototyping

# %%
df2
# Out:
#        id2        id           upc          brand  \
# 0        1  14249992   64109216245         Draper
# 1        2  10928662    1034383417          Epson
# 2        3  11961447   80844700031  Comprehensive
# 3        4  13044637   79006932160         D-Link
# 4        5  13214131    6503081691       StarTech
# 5        6  13215629    2120052175             3M
# 6        7  13216122    8869859138             HP
# 7        8  13216211   78541410985      Visioneer
# 8        9  13221597    1250261176        Brother
# 9       10  13215623    5113580710             3M
# 10      11  13969168    9305379797          LaCie
# 11      12  14250554   64109212230         Draper
# 12      13  14251773   64109210858         Draper
# 13      14  14560013   89745000234        Stanley
# 14      15  14906581  878260002214      Gear Head
# 15      16  14915557    7278205029          Avery
# 16      17  17038254   77865605376            XFX
# 17      18  17054419   78927019146      SKB Cases
# 18      19  14922512   68602439701       INNOVERA
# 19      20  14929239    8869862919             HP
# 20      21  14931817    4310006622           Mead
# 21      22  15029113   88131700513         IOGEAR
# 22      23  15118120    3413802305        Quartet
# 23      24  15140580    7278206878          Avery
# 24      25  15379706   81265801087       Aluratek
# 25      26  15412328   88442058870             HP
# 26      27  15421408   64953260962     CyberPower
# 27      28  15571931   84593302868        Tribeca
# 28      29  15686587    7721806627            NaN
# 29      30  15751827   84476701248         Vantec
# ...    ...       ...           ...            ...
# 2524  2525  13446771   89166400233          SUMAS
# 2525  2526  13728166    9116323182         Genius
# 2526  2527  14059795    9492259094        Mustang
# 2527  2528  14118868    2394297017       Verbatim
# 2528  2529  14249227   64109212962         Draper
# 2529  2530  14249394   64109210328         Draper
# 2530  2531  14250726   64109213359         Draper
# 2531  2532  15523571   84180801048      Night Owl
# 2532  2533  14251385   64109214832         Draper
# 2533  2534  14251706   64109212818         Draper
# 2534  2535  14915343    1842111906     Rubbermaid
# 2535  2536  14916129   73464602490        Lexmark
# 2536  2537  17052793   71640852642    Gator Cases
# 2537  2538  16677018   84359101238        Corsair
# 2538  2539  16794935    1250262677        Brother
# 2539  2540  14917684    1493519250          Ghent
# 2540  2541  14958773   76055911681          ZyXEL
# 2541  2542  15143657   71706840685        Da-Lite
# 2542  2543  15188215   87681800530          Elite
# 2543  2544  15268226   88410200585   Coolermaster
# 2544  2545  16352173    2324455017          Crown
# 2545  2546  14251622   64109215065         Draper
# 2546  2547  15542925   71706862929        Da-Lite
# 2547  2548  14250505   64109212208         Draper
# 2548  2549  15819299   18821800032        Sabrent
# 2549  2550  16360703    5114123170             3M
# 2550  2551  16553062   89979400511            HTC
# 2551  2552  16637140   89807400111           Dell
# 2552  2553   9714616   72286814877         Belkin
# 2553  2554  10913180   84367700007       Motorola
#
#                                   groupname  \
# 0                     Electronics - General
# 1                                  Monitors
# 2                            TV Accessories
# 3                          Garden - General
# 4                     Electronics - General
# 5                                 Furniture
# 6     Stationery  & amp ;  Office Machinery
# 7                     Electronics - General
# 8     Stationery  & amp ;  Office Machinery
# 9                     Electronics - General
# 10                    Electronics - General
# 11                    Electronics - General
# 12                    Electronics - General
# 13                    Electronics - General
# 14                    Electronics - General
# 15    Stationery  & amp ;  Office Machinery
# 16                    Electronics - General
# 17                    Electronics - General
# 18                                  Storage
# 19    Stationery  & amp ;  Office Machinery
# 20    Stationery  & amp ;  Office Machinery
# 21                               Networking
# 22    Stationery  & amp ;  Office Machinery
# 23    Stationery  & amp ;  Office Machinery
# 24                          MP3 Accessories
# 25                                 Printers
# 26                    Electronics - General
# 27                    Electronics - General
# 28                              House wares
# 29                    Electronics - General
# ...                                     ...
# 2524                            Car Stereos
# 2525                                   Mice
# 2526                  Electronics - General
# 2527                        MP3 Accessories
# 2528                  Electronics - General
# 2529                  Electronics - General
# 2530                  Electronics - General
# 2531                       Garden - General
# 2532                  Electronics - General
# 2533                  Electronics - General
# 2534  Stationery  & amp ;  Office Machinery
# 2535                               Printers
# 2536                  Electronics - General
# 2537                             USB Drives
# 2538                               Printers
# 2539  Stationery  & amp ;  Office Machinery
# 2540                             Networking
# 2541                  Electronics - General
# 2542                  Electronics - General
# 2543                  Electronics - General
# 2544                              Home Care
# 2545                  Electronics - General
# 2546                  Electronics - General
# 2547                  Electronics - General
# 2548                             USB Drives
# 2549  Stationery  & amp ;  Office Machinery
# 2550                  Electronics - General
# 2551                               Printers
# 2552                  Electronics - General
# 2553                    Walkie-Talkie / FRS
#
#                                                   title    price  \
# 0                    Draper Infrared Remote Transmitter    58.45
# 1      Epson 1500 Hours 200W UHE Projector Lamp ELPLP12   438.84
# 2     Comprehensive Two-Piece 75 Precision BNC Jack ...    59.25
# 3                        D-Link DCS-1100 Network Camera    99.82
# 4         StarTech.com RKPW247015 24 Outlet Power Strip    59.00
# 5              3M FR530CB Ergonomic Adjustable Footrest    67.88
# 6      HP C6020B Coated Paper 1 roll 36-inches x 150 ft    49.88
# 7       Visioneer RW120-WU RoadWarrior Sheetfed Scanner   199.98
# 8     Brother DK2113 QL Label Printers Continuous Le...    64.88
# 9                              3M MW310LE Gel Mouse Pad    17.88
# 10         LaCie Formoa 15  MacBook Carrying Case Black    15.00
# 11    Draper High Contrast Grey Targa Electric Scree...  1730.95
# 12    Draper AT1200 Access MultiView Series E Acoust...  4375.95
# 13                      Stanley 500 Watt Power Inverter    34.88
# 14    Gear Head Quick 1.3MP Webcam with Night Vision...    15.98
# 15    Avery Self-Adhesive Filing Labels 1 3 Cut 3-7 ...    21.47
# 16        XFX Radeon HD6850 PCIE 1GB DDR5 Graphics Card   195.00
# 17    SKB Cases PH Series Pull Handle Case 11 1 2 H ...   214.99
# 18    Innovera CD DVD Pocket with Built-In Label Tab...     5.28
# 19    HP 80 Ink Printhead Printhead Cleaner Black C4...   268.79
# 20              Mead Spiral Bound Notebook College Rule     3.88
# 21     IOGEAR 2-Port MiniView Micro USB PLUS KVM Switch    37.57
# 22    Quartet Cork Bulletin Board Natural Cork Fiber...    91.44
# 23    Avery Shipping Labels for Color Laser   Copier...    16.67
# 24    Aluratek Deluxe Leather Travel Case for the Li...    23.10
# 25             HP CE278A Black LaserJet Print Cartridge    69.84
# 26    Cyber Power PFC 1000VA LCD Sinewave Adaptive I...   151.00
# 27    Tribeca Dallas Cowboys 15  Sleeve for MacBook ...    31.88
# 28     Tablemate Plastic Dinnerware 6 Inch Plates 125pk    18.97
# 29    Vantec NexStar MX Dual 3.5  SATA Hard Drive En...    49.71
# ...                                                 ...      ...
# 2524  Sumas Media SMC-Frame-S1 Rear Camera License P...    49.00
# 2525  Genius Agama M-300 Retractable Mini Mouse - Op...    10.00
# 2526            Mustang 92 Manual Screen in Matte White   104.00
# 2527  Verbatim 100-Pack 16X DataLifePlus Shiny Silve...    29.98
# 2528  Draper Matte White Baronet Electric Screen - A...   435.15
# 2529  Draper HiDef Grey Premier Electric Screen  - H...  1682.45
# 2530  Draper Glass Beaded Access Series M Manual Scr...  1113.95
# 2531  Night Owl Security Products Wired Color Securi...    49.71
# 2532  Draper Cineflex Cineperm Fixed Frame Screen - ...   416.70
# 2533  Draper IRUS Rear Projection Screen with System...  4196.70
# 2534  Rubbermaid Extra Deep Desk Drawer Director Tra...     7.94
# 2535  Lexmark 12A8425 Black High-Yield Toner Print C...   302.40
# 2536  Gator Cases ATA Molded Utility Case 11.7 x 16....   139.99
# 2537     Corsair Flash Voyager 32GB USB 3.0 Flash Drive    74.88
# 2538  Brother TN450 Black Toner Cartridge High Yield...    48.88
# 2539                   Ghent Triumph Display Easel Gray    26.09
# 2540  ZyXEL HomePlug AV 200Mbps Powerline Wall Plug ...    47.92
# 2541  Da-Lite Matte White Designer Model B with Fabr...   152.99
# 2542  Elite Screens 92  VMAX92UWV2 Electric Projecti...   319.59
# 2543        Cooler Master 120mm Silent Blade Master Fan    15.88
# 2544  Crown Mat-A-Dor Entrance Antifatigue Rubber Ma...    55.97
# 2545  Draper HiDef Grey ShadowBox Clarion Fixed Fram...   985.99
# 2546  Da-Lite Da-Tex Rear Tensioned Advantage Electr...  2549.38
# 2547  Draper Glass Beaded Targa Electric Screen  - H...   807.45
# 2548    Sabrent 6-in-1 USB 2.0 Flash Memory Card Reader    10.98
# 2549   3M Dry-Erase Board Porcelain 6 x4 Aluminum Frame   579.29
# 2550                      HTC MyTouch 3G White Unlocked   199.00
# 2551                            Dell Series 2 Color Ink    35.97
# 2552  Belkin Pro Series High Integrity Monitor Cable...     7.88
# 2553  MOTOROLA MJ270R 27 MILE TWO WAY RADIO WITH 22 ...    47.11
#
#                                              shelfdescr  \
# 0     Infrared transmitter. 3-button operation for i...
# 1                                                   NaN
# 2     Comprehensive s True 75 connectors eliminate i...
# 3     Surveillance Network Camera  Built-in Omni-dir...
# 4     Fits most 42U racks and equipment cabinets  10...
# 5     Material Steel  Features Non-skid  Color Charc...
# 6     Bright white coated paper  For use with Inkjet...
# 7       Sheetfed color scanner  600 dpi  USB connection
# 8     Clear label tape  Ideal for sign and banner cr...
# 9     Mouse Pad  Features Antimicrobial non-skid bas...
# 10    Bubble protection and soft inside lining Three...
# 11    Targa electric projection screen. Ideal for au...
# 12    The Access MultiView Series E offers total fle...
# 13    500 watts of continuous power Battery clamps D...
# 14    Up to 1.3 megapixel image capture 640 x 480 vi...
# 15    Clear 1 3 cut filing labels Clear labels virtu...
# 16    800 MHz GPU core clock 4200 MHz memory speed 2...
# 17    Telescoping retractable pull-handle convenienc...
# 18    CD pocket with built-in tab for adhesive ID la...
# 19    Print cartridge printhead and printhead cleane...
# 20    3-hole punched College rule Sheet size 8  Avai...
# 21    6 molded-in cables simplify setup Full support...
# 22    Self-healing cork surface Perfect for school h...
# 23    Matte white mailing labels Guaranteed printer ...
# 24    Premium quality hand-stitched leather Held sec...
# 25    1 print cartridge Color black Printing technol...
# 26    Intelligent LCD diagnostic display Automatic v...
# 27    Fits MacBook Pros and 15  laptops Shock absorb...
# 28                                                  NaN
# 29    Supports dual SATA I II hard drives Front vent...
# ...                                                 ...
# 2524  Infrared Night Vision Waterproof design 170-de...
# 2525  USB plug-and-play 74mm size retractable cable ...
# 2526  Features -Manual wall mount screen. -Case colo...
# 2527  Capacity 4.7GB Advanced azo recording dye Comp...
# 2528  The Baronet electric projection screen is easy...
# 2529  Premier electric wall or ceiling projection sc...
# 2530  The Access Series M. Sleek white extruded alum...
# 2531   Color Black 60 of cable Up to 45 of night vision
# 2532  Snap-On projection screen with aluminum frame....
# 2533  The Infinite Resolution Unifromity Screen is d...
# 2534                   Durable Deep bins Seven sections
# 2535  1 print cartridge Color Black Yields up to 12 ...
# 2536  Features -Constructed of polyethylene. -Upgrad...
# 2537      Capacity 32GB USB 3.0 interface Plug and play
# 2538  Page Yield 2 600 pages  Fine particles create ...
# 2539  Height adjustable from 27  Holds up to 25 lbs ...
# 2540  Plug and play connectivity Multi-colored LED r...
# 2541  Features -Fabric wrapped case with coordinatin...
# 2542  MaxWhite 1.1 gain black-backed material 160-de...
# 2543  Fan Speed 600-1200 rpm Anti-vibration rubber p...
# 2544                                                NaN
# 2545  Viewing surface snaps to the back of a 1-1 2 e...
# 2546  Features -Same great design as our Advantage  ...
# 2547  Targa electric projection screen. Ideal for au...
# 2548  6-in-1 card reader A compact solution to acces...
# 2549  3M Aluminum Frame Porcelain Dry-erase Board Dr...
# 2550  Android OS v1 3.15MP camera Video recording at...
# 2551            Color Color For Dell A940 A960 printers
# 2552  The Belkin Pro Series High Integrity Monitor C...
# 2553  The Motorola Talkabout MJ270 is the ideal emer...
#
#                                              shortdescr  \
# 0                                                   NaN
# 1                       Epson ELPLP12  Replacement Lamp
# 2                                                   NaN
# 3     The D-Link DCS-1100 Network Camera comes with ...
# 4     The StarTech.com RKPW247015 24 Outlet Power St...
# 5     This adjustable footrest offers an ergonomic d...
# 6     The HP C6020B Coated Paper is ideal for color-...
# 7     The Visioneer RoadWarrior is the perfect compa...
# 8     Make sign and banner creation a breeze. Make t...
# 9     Mouse pad with wrist rest features 3M Precise ...
# 10    The LaCie ForMoa line of carrying cases is a c...
# 11                                                  NaN
# 12                                                  NaN
# 13    The 500 Watt Power Inverter has 500 continuous...
# 14    Chat face-to-face with your friends - even whe...
# 15    Use the Avery Self-Adhesive Filing Labels for ...
# 16    The AMD Radeon HD 6850 ushers in a new era of ...
# 17                                                  NaN
# 18    The Innovera CD DVD Pocket with Built-In Label...
# 19    The HP 80 Ink Printhead Printhead Cleaner is t...
# 20    Stay organized with with this Spiral Bound Not...
# 21    Introducing the 2-port MiniView Micro USB PLUS...
# 22    The Quartet Cork Bulletin Board is an affordab...
# 23    Create labels that get noticed These labels ar...
# 24    Aluratek s deluxe leather travel case is desig...
# 25    Get a great value for everyday business printi...
# 26    Protect your computer system or network from p...
# 27    Tribeca s Dallas Cowboys Sleeve fits MacBook P...
# 28                                                  NaN
# 29    The Vantec NexStar MX Dual 3.5  SATA Hard Driv...
# ...                                                 ...
# 2524  See what s behind you with the Sumas Media SMC...
# 2525  The M300 retractable mini laptop mouse from Ge...
# 2526                                                NaN
# 2527  Spend your time developing exciting DVD video ...
# 2528                                                NaN
# 2529                                                NaN
# 2530                                                NaN
# 2531  The Night Owl Security Products Wired Color Se...
# 2532                                                NaN
# 2533                                                NaN
# 2534  The Rubbermaid Extra Deep Desk Drawer Director...
# 2535  The Lexmark 12A8425 Black High-Yield Toner Pri...
# 2536                                                NaN
# 2537  The Corsair Flash Voyager 32GB USB Flash Drive...
# 2538  The Brother Black High Yield Toner Cartridge i...
# 2539  A great value in a display easel the Ghent Tri...
# 2540  Designed for high performance the ZyXEL HomePl...
# 2541                                                NaN
# 2542  The Elite Screens 92  VMAX92UWV2 Electric Proj...
# 2543  When ultra-high performance coolers demand add...
# 2544  Entrance and anti-fatigue mats with 2 400 rubb...
# 2545                                                NaN
# 2546                                                NaN
# 2547                                                NaN
# 2548  The Sabrent 6-in-1 USB 2.0 Flash Memory Card R...
# 2549                                                NaN
# 2550  The HTC MyTouch 3G features a Gorilla Glass di...
# 2551  The Dell Series 2 Color Ink provides consisten...
# 2552  The Belkin Pro Series High Integrity Monitor C...
# 2553  The Motorola Talkabout MJ270 is the ideal emer...
#
#                                               longdescr  \
# 0     DR1143Infrared transmitter. 3-button operation...
# 1     EPSON ELPLP12 1500HRS 200V REPL LAMP FOR LAMP ...
# 2     CH1151Comprehensive s True 75 connectors elimi...
# 3     Surveillance Network Camera  Built-in Omni-dir...
# 4     24 Outlet Power Strip solution for your rackmo...
# 5     Material Steel  Features Non-skid  Color Charc...
# 6     Bright white coated paper  For use with Inkjet...
# 7     Sheetfed color scanner  Lightweight and portab...
# 8     Clear label tape  Ideal for sign and banner cr...
# 9     Mouse Pad  Features Antimicrobial non-skid bas...
# 10    Key Features Bubble protection and soft inside...
# 11    DR5377Targa electric projection screen. Ideal ...
# 12    DR7989The Access MultiView Series E offers tot...
# 13    500 watts of continuous power 2 110 power outl...
# 14    Gear Head 1.3MP Webcam Up to 1.3 megapixel ima...
# 15    Avery Self-Adhesive Filing Labels Clear 1 3 cu...
# 16    AMD Radeon HD6850 PCIE 1GB DDR5 Graphics Card ...
# 17    SK1027Telescoping retractable pull-handle conv...
# 18    Innovera 25pk CD DVD Pocket with Built-In Labe...
# 19    HP 80 Ink Printhead Printhead Cleaner Print ca...
# 20    Mead Spiral Bound Notebook 3-hole punched Coll...
# 21    IOGEAR 2-Port MiniView Micro USB PLUS KVM Swit...
# 22    Quartet Cork Bulletin Board Self-healing cork ...
# 23    Avery Shipping Labels for Color Laser and Copi...
# 24    Aluratek Deluxe Leather Travel Case for the LI...
# 25    HP CE278A Black LaserJet Print Cartridge 1 pri...
# 26    Cyber Power PFC 1000VA LCD Sinewave Adaptive I...
# 27    Tribeca Dallas Cowboys 15  laptops Shock absor...
# 28            6 inch White Disposable dinnerware Sturdy
# 29    Vantec NexStar MX Dual 3.5  SATA Hard Drive En...
# ...                                                 ...
# 2524  Key Features 24 built-in IR LED sensor on fram...
# 2525  Key Features USB plug-and-play interface for e...
# 2526  MSU1034  Features Manual wall mount screen Cas...
# 2527  Key Features Capacity 4.7GB Advanced azo recor...
# 2528  DR3129The Baronet electric projection screen i...
# 2529  DR3459Premier electric wall or ceiling project...
# 2530  DR5795The Access Series M. Sleek white extrude...
# 2531  Night Owl Security Products Wired Color Securi...
# 2532  DR7363Snap-On projection screen with aluminum ...
# 2533  DR7898The Infinite Resolution Unifromity Scree...
# 2534  Rubbermaid Extra Deep Desk Drawer Director Tra...
# 2535  Lexmark 12A8425 Black High-Yield Toner Print C...
# 2536  GC2595  Features Constructed of polyethylene U...
# 2537  Corsair Flash Voyager 32GB USB 3.0 Flash Drive...
# 2538  Brother Black High Yield Toner Cartridge Color...
# 2539  Ghent Triumph Display Easel Holds up to 25 lbs...
# 2540  ZyXEL HomePlug AV Powerline Wall Plug Adapter ...
# 2541  DL6754 Features Fabric wrapped case with coord...
# 2542  Elite Screens 92  receiver 3-way wall switch O...
# 2543  Cooler Master 120mm Silent Blade Master Fan We...
# 2544  Keeps home and office free from dirt and debri...
# 2545  DR7786Viewing surface snaps to the back of a 1...
# 2546  DL4678 Features Same great design as our Advan...
# 2547  DR5156Targa electric projection screen. Ideal ...
# 2548  Sabrent 6-in-1 USB 2.0 Flash Memory Card Reade...
# 2549  TM5788 3M Aluminum Frame Porcelain Dry-erase B...
# 2550  HTC MyTouch 3G Sound and Music Vibration polyp...
# 2551  Dell Series 2 Color Ink Color Color For Dell A...
# 2552  Technical Information   Cable Type  Monitor   ...
# 2553  Includes an emergency alert feature allowing y...
#
#                                                imageurl          modelno  \
# 0     http :  /  / i.walmartimages.com / i / mp / 00...           121066
# 1     http :  /  / i.walmartimages.com / i / p / 00 ...          ELPLP12
# 2     http :  /  / i.walmartimages.com / i / mp / 00...        BJ-2C7559
# 3     http :  /  / i.walmartimages.com / i / p / 00 ...         DCS-1100
# 4     http :  /  / i.walmartimages.com / i / p / 00 ...       RKPW247015
# 5     http :  /  / i.walmartimages.com / i / p / 00 ...          FR530CB
# 6     http :  /  / i.walmartimages.com / i / p / 00 ...           C6020B
# 7     http :  /  / i.walmartimages.com / i / p / 00 ...         RW120-WU
# 8     http :  /  / i.walmartimages.com / i / p / 00 ...           DK2113
# 9     http :  /  / i.walmartimages.com / i / p / 00 ...          MW310LE
# 10    http :  /  / i.walmartimages.com / i / p / 00 ...           130935
# 11    http :  /  / i.walmartimages.com / i / mp / 00...           116263
# 12    http :  /  / i.walmartimages.com / i / mp / 00...           106018
# 13    http :  /  / i.walmartimages.com / i / p / 00 ...            PC509
# 14    http :  /  / i.walmartimages.com / i / p / 08 ...        WC1200RED
# 15    http :  /  / i.walmartimages.com / i / p / 00 ...             5029
# 16    http :  /  / i.walmartimages.com / i / p / 00 ...       HD685XZNDC
# 17    http :  /  / i.walmartimages.com / i / mp / 00...      3SKB-1914MR
# 18    http :  /  / i.walmartimages.com / i / p / 00 ...            39701
# 19    http :  /  / i.walmartimages.com / i / p / 00 ...           C4890A
# 20    http :  /  / i.walmartimages.com / i / p / 00 ...             6622
# 21    http :  /  / i.walmartimages.com / i / p / 00 ...        GCS632UW6
# 22    http :  /  / i.walmartimages.com / i / p / 00 ...             2305
# 23    http :  /  / i.walmartimages.com / i / p / 00 ...              NaN
# 24    http :  /  / i.walmartimages.com / i / p / 00 ...          2782753
# 25    http :  /  / i.walmartimages.com / i / p / 00 ...        HP CE278A
# 26    http :  /  / i.walmartimages.com / i / p / 00 ...     CP1000PFCLCD
# 27    http :  /  / i.walmartimages.com / i / p / 00 ...          FVA2868
# 28    http :  /  / i.walmartimages.com / i / p / 00 ...           6644WH
# 29    http :  /  / i.walmartimages.com / i / p / 00 ...     NST-400MX-S2
# ...                                                 ...              ...
# 2524  http :  /  / i.walmartimages.com / i / p / 00 ...     SMC-FRAME-S1
# 2525  http :  /  / i.walmartimages.com / i / p / 00 ...      31010615100
# 2526  http :  /  / i.walmartimages.com / i / mp / 00...      SC-M92D16:9
# 2527  http :  /  / i.walmartimages.com / i / p / 00 ...            97017
# 2528  http :  /  / i.walmartimages.com / i / mp / 00...           129003
# 2529  http :  /  / i.walmartimages.com / i / mp / 00...           101309
# 2530  http :  /  / i.walmartimages.com / i / mp / 00...           203039
# 2531  http :  /  / i.walmartimages.com / i / p / 00 ...     CAM-CM01-245
# 2532  http :  /  / i.walmartimages.com / i / mp / 00...           251013
# 2533  http :  /  / i.walmartimages.com / i / mp / 00...           125106
# 2534  http :  /  / i.walmartimages.com / i / p / 00 ...              NaN
# 2535  http :  /  / i.walmartimages.com / i / p / 00 ...          12A8425
# 2536  http :  /  / i.walmartimages.com / i / mp / 00...  GXDF-1116-5-TSA
# 2537  http :  /  / i.walmartimages.com / i / p / 00 ...      CMFVY3-32GB
# 2538  http :  /  / i.walmartimages.com / i / p / 00 ...            TN450
# 2539  http :  /  / i.walmartimages.com / i / p / 00 ...            19250
# 2540  http :  /  / i.walmartimages.com / i / p / 00 ...         PLA401V3
# 2541  http :  /  / i.walmartimages.com / i / mp / 00...            73113
# 2542  http :  /  / i.walmartimages.com / i / p / 00 ...       VMAX92UWV2
# 2543  http :  /  / i.walmartimages.com / i / p / 00 ...  R4-BMBS-20PK-R0
# 2544  http :  /  / i.walmartimages.com / i / p / 00 ...         MASR42BK
# 2545  http :  /  / i.walmartimages.com / i / mp / 00...           253085
# 2546  http :  /  / i.walmartimages.com / i / mp / 00...            85375
# 2547  http :  /  / i.walmartimages.com / i / mp / 00...           116241
# 2548  http :  /  / i.walmartimages.com / i / p / 00 ...          CRW-EXT
# 2549  http :  /  / i.walmartimages.com / i / mp / 00...              NaN
# 2550  http :  /  / i.walmartimages.com / i / p / 00 ...       Mytouch 3G
# 2551  http :  /  / i.walmartimages.com / i / p / 00 ...         330-0048
# 2552  http :  /  / i.walmartimages.com / i / p / 00 ...        F3H982-06
# 2553  http :  /  / i.walmartimages.com / i / p / 00 ...           MJ270R
#
#       shipweight  length  width  height
# 0          2.000     NaN    NaN     NaN
# 1          0.950    6.75   5.75    5.50
# 2          0.050     NaN    NaN     NaN
# 3            NaN     NaN    NaN     NaN
# 4          5.250   72.50   2.50    1.50
# 5         10.500   21.60  13.50    4.05
# 6          9.780   33.98   3.83    3.83
# 7          1.850   11.40   2.00    1.50
# 8          0.550    4.50   4.50    3.60
# 9          0.950    9.63   7.65    0.36
# 10         1.300   16.10  11.50    0.90
# 11       100.000     NaN    NaN     NaN
# 12        96.000     NaN    NaN     NaN
# 13         2.600    9.75   5.00    2.25
# 14         1.500    7.20   4.40    3.50
# 15         0.412     NaN    NaN     NaN
# 16         1.080   32.40  16.40   10.00
# 17        14.000   19.00  14.00   10.00
# 18         0.386     NaN    NaN     NaN
# 19         1.790     NaN    NaN     NaN
# 20         0.837     NaN    NaN     NaN
# 21         1.150   10.00   7.00    3.00
# 22        16.160     NaN    NaN     NaN
# 23           NaN     NaN    NaN     NaN
# 24         0.500    6.25   4.75    1.00
# 25         1.800    1.00   1.00    1.00
# 26        19.150   13.50  11.20    6.30
# 27         0.850   15.88  12.60    1.13
# 28         1.859    6.00   6.00    5.70
# 29         5.000   10.00   7.00    6.00
# ...          ...     ...    ...     ...
# 2524       1.250   12.25   8.25    1.25
# 2525       1.000    7.30   4.40    2.80
# 2526      32.000     NaN    NaN     NaN
# 2527       3.580    6.00   4.75    4.75
# 2528      26.000     NaN    NaN     NaN
# 2529      81.000     NaN    NaN     NaN
# 2530     111.000     NaN    NaN     NaN
# 2531       2.750   12.50   3.90    0.10
# 2532      26.000     NaN    NaN     NaN
# 2533     308.000     NaN    NaN     NaN
# 2534         NaN     NaN    NaN     NaN
# 2535       3.850     NaN    NaN     NaN
# 2536      13.000   18.00  12.00    7.00
# 2537       0.900    7.50   5.50    0.25
# 2538       1.750   14.50   7.90    4.50
# 2539       5.000     NaN    NaN     NaN
# 2540       0.900   15.00   9.40    4.00
# 2541      18.000     NaN    NaN     NaN
# 2542      26.000   88.00   5.50    5.50
# 2543       0.500    7.10   5.10    1.20
# 2544      12.000   34.00   6.00    6.00
# 2545      42.000     NaN    NaN     NaN
# 2546     124.000     NaN    NaN     NaN
# 2547      68.000     NaN    NaN     NaN
# 2548       1.000   10.00   8.00    2.80
# 2549      42.000     NaN    NaN     NaN
# 2550       0.850    4.45   2.19    0.58
# 2551       7.000    5.50   3.86    1.26
# 2552       0.600    6.30   3.60    0.90
# 2553       1.550    7.80   2.40    1.30
#
# [2554 rows x 16 columns]

# %%
import pandas as pd
import numpy as np
import pickle as pkl
import argparse as ap

import os
import re
import string
import html

from collections import defaultdict

# parse command line arguments
source_dir = '../data/raw/amazon-walmart'
dest_dir = '../data/converted/amazon-walmart'
mapping_file = '../data/embeddings/glove-300.map'
column_idxs = [3,4,5,7,8,9,10]

verbose = True

set1 = 'set1.csv'
set2 = 'set2.csv'
matches = 'matches.csv'

# %%
if verbose:
    print('Loading datasets and maps.')
# load data
# df_pos is loaded so that it can be copied to destination directory
df1 = pd.read_csv(os.path.join(source_dir, set1), encoding = "latin1")
df2 = pd.read_csv(os.path.join(source_dir, set2), encoding = "latin1")
df_pos = pd.read_csv(os.path.join(source_dir, matches), encoding = "latin1")

# load double dictionary
with open(mapping_file, 'rb') as f:
    map = pkl.load(f)

# change word2idx to a default dictionary that outputs 0 for unknown tokens
map['word2idx'] = defaultdict(int, map['word2idx'])
# Out:
# Loading datasets and maps.

# %%
def clean_text(x):
    "formats a single string"
    if not isinstance(x, str):
        return 'NaN'
    
    # separate possessives with spaces
    x = x.replace('\'s', ' \'s')
    
    # convert html escape characters to regular characters
    x = html.unescape(x)
    
    # separate punctuations with spaces
    def pad(x):
        match = re.findall(r'.', x[0])[0]
        match_clean = ' ' + match + ' '
        return match_clean
    rx = r'\(|\)|/|!|#|\$|%|&|\\|\*|\+|,|:|;|<|=|>|\?|@|\[|\]|\^|_|{|}|\||'
    rx += r'`|~'
    x = re.sub(rx, pad, x)
    
    # remove decimal parts of version numbers
    def v_int(x):
        return re.sub('\.\d+','',x[0])
    x = re.sub(r'v\d+\.\d+', v_int, x)
    
    return x

if verbose:
    print('Cleaning the following columns from set1:')
    for column in df1.columns[column_idxs]:
        print(column, end=' ')
    print()
    print('Cleaning the following columns from set2:')
    for column in df2.columns[column_idxs]:
        print(column, end=' ')
    print()

df1.iloc[:, column_idxs] = df1.iloc[:, column_idxs].applymap(clean_text)
df2.iloc[:, column_idxs] = df2.iloc[:, column_idxs].applymap(clean_text)
# Out:
# Cleaning the following columns from set1:
# brand pcategory1 title techdetails proddescrshort proddescrlong imageurl
# Cleaning the following columns from set2:
# brand groupname title shelfdescr shortdescr longdescr imageurl

# %%
def record2idx(x):
    x = x.split()
    for i, token in enumerate(x):
        idx = map['word2idx'][token]
        if idx == 0:
            idx = map['word2idx'][token.lower()]
        if idx == 0:
            idx = map['word2idx'][string.capwords(token)]
        if idx == 0:
            idx = map['word2idx'][token.upper()]
        x[i] = idx
    return x

if verbose:
    print('Converting tokens to indices.')
df1.iloc[:, column_idxs] = df1.iloc[:, column_idxs].applymap(record2idx)
df2.iloc[:, column_idxs] = df2.iloc[:, column_idxs].applymap(record2idx)

if not os.path.isdir(dest_dir):
    os.mkdir(dest_dir)
    if verbose:
        print('Creating destination directory')

# %%
    
df1.to_csv(os.path.join(dest_dir, set1), index=False)
df2.to_csv(os.path.join(dest_dir, set2), index=False)
df_pos.to_csv(os.path.join(dest_dir, matches), index=False)
# Out:
# Overwriting convert-text.py
